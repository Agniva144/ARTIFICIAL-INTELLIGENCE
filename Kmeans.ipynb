# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv('D:\AI(edu)\Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X=dataset.iloc[:,[3]].values

# %%
X
# Out:
# array([[ 15],
#        [ 15],
#        [ 16],
#        [ 16],
#        [ 17],
#        [ 17],
#        [ 18],
#        [ 18],
#        [ 19],
#        [ 19],
#        [ 19],
#        [ 19],
#        [ 20],
#        [ 20],
#        [ 20],
#        [ 20],
#        [ 21],
#        [ 21],
#        [ 23],
#        [ 23],
#        [ 24],
#        [ 24],
#        [ 25],
#        [ 25],
#        [ 28],
#        [ 28],
#        [ 28],
#        [ 28],
#        [ 29],
#        [ 29],
#        [ 30],
#        [ 30],
#        [ 33],
#        [ 33],
#        [ 33],
#        [ 33],
#        [ 34],
#        [ 34],
#        [ 37],
#        [ 37],
#        [ 38],
#        [ 38],
#        [ 39],
#        [ 39],
#        [ 39],
#        [ 39],
#        [ 40],
#        [ 40],
#        [ 40],
#        [ 40],
#        [ 42],
#        [ 42],
#        [ 43],
#        [ 43],
#        [ 43],
#        [ 43],
#        [ 44],
#        [ 44],
#        [ 46],
#        [ 46],
#        [ 46],
#        [ 46],
# ...
